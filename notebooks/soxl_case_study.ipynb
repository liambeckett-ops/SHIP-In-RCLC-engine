# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 🔍 SOXL Case Study\n",
    "Testing SHIP-In + RCLC decision architecture on tactical signal input.\n",
    "\n",
    "**Goals:**\n",
    "- Validate decision-making loop\n",
    "- Simulate signal memory feedback\n",
    "- Visualize reinforcement patterns"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "from src.core_engine import CognitiveCore\n",
    "from src.execution_manager import ExecutionManager\n",
    "from src.strategy_handler import StrategyHandler"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "core = CognitiveCore()\n",
    "exec_mgr = ExecutionManager()\n",
    "strategy = StrategyHandler()\n",
    "\n",
    "signal = {\"ticker\": \"SOXL\", \"confidence\": 0.81}\n",
    "response = core.process_input(signal)\n",
    "decision = strategy.execute(response)\n",
    "exec_mgr.simulate_trade(decision['decision'], price=19.42)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "exec_mgr.report()"
   ]
  }
 ],
 "metadata": {},
 "nbformat": 4,
 "nbformat_minor": 5
}
